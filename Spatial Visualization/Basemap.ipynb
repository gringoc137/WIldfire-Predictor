# %%
import numpy as np
import os
import matplotlib.pyplot as plt
os.environ["PROJ_LIB"] = r'C:\Users\Mahe\Anaconda3\pkgs\proj4-5.2.0-ha925a31_1\Library\share'
from mpl_toolkits.basemap import Basemap
from netCDF4 import Dataset

# %%
lst_data=Dataset(r'C:\Users\Mahe\Desktop\MOD11A1.006_1km_aid0001b.nc','r')
ndvi_data=Dataset(r'C:\Users\Mahe\Desktop\wildfires\ndvi\MOD13A2.006_1km_aid0001.nc','r')
vcr_data=Dataset(r'C:\Users\Mahe\Desktop\wildfires\treecov\MOD44B.006_250m_aid000199(2).nc','r')
prec_data=Dataset(r'C:\Users\Mahe\Desktop\wildfires\athuldineshHHunS1\CDR_31_2020-06-24033126am_2019.nc','r')

# %%
#lst variables
lat=lst_data.variables['lat'][:]
lon=lst_data.variables['lon'][:]
lst=lst_data.variables['LST_Day_1km']
lstn=lst_data.variables['LST_Night_1km']

#ndvi variables
nd=ndvi_data.variables['_1_km_16_days_NDVI']
nlat=ndvi_data.variables['lat'][:]
nlon=ndvi_data.variables['lon'][:]

#vcr variables
vc=vcr_data.variables['Percent_NonTree_Vegetation'][:]
vlat=vcr_data.variables['lat'][:]
vlon=vcr_data.variables['lon'][:]

#prec variables
plat=prec_data.variables['lat'][:]
plon=prec_data.variables['lon'][:]
pre=prec_data.variables['precip']

# %%
t_dat=data.variables['time'][:]
lats=data.variables['lat'][:]
lons=data.variables['lon'][:]
lst=data.variables['LST_Day_1km'][:]

# %%
mp = Basemap(projection='merc',
            llcrnrlon=-127.145848,
            llcrnrlat= 28.614927,
            urcrnrlon=-110.662860,
            urcrnrlat= 43.373693,
            resolution='i')
# Out:
# C:\Users\Mahe\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %%
lon, lat= np.meshgrid(lon,lat)
x,y= mp(lon,lat)

# %%
#daywise heatmap of lst day values
cols = mp.pcolor(x,y,np.squeeze(lst[0,:,:]),cmap='jet')
mp.drawcoastlines()
mp.drawstates()
mp.drawlsmask(ocean_color='aqua',lakes=True)
mp.drawcountries()
cbar = mp.colorbar(cols,location= 'right',pad='10%')
plt.title('Land Surface Temperature on 1st june 2019')
plt.show()
# Out:
# C:\Users\Mahe\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   after removing the cwd from sys.path.
# C:\Users\Mahe\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %%
#save all heatmaps to create animation
""""days=np.arange(0,31)

for i in days:
    cols = mp.pcolor(x,y,np.squeeze(lst[i,:,:]),cmap='jet')
    mp.drawcoastlines()
    mp.drawstates()
    mp.drawcountries()
    cbar = mp.colorbar(cols,location= 'right',pad='10%')
    plt.title('Land Surface Temperature on day:'+str(i+1))
    plt.clim(250,350)
    plt.savefig(r'C:\Users\Mahe\Desktop\wildfires\lst_gif'+'\\'+str(i+1)+'.jpg')
    plt.clf()
    #plt.show()"""

# %%
"""data = Dataset(r'C:\Users\Mahe\Desktop\wildfires\therm\VNP14A1.001_1km_aid0001(2).nc','r')
t_dat=data.variables['time'][:]
lats=data.variables['lat'][:]
lons=data.variables['lon'][:]
frp=data.variables['MaxFRP'][:]

# %%
lon, lat= np.meshgrid(nlon,nlat)
x,y= mp(lon,lat)
# Out:
# C:\Users\Mahe\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.

# %%
cols = mp.pcolor(x,y,np.squeeze(nd[0,:,:]),cmap='jet')
mp.drawcoastlines()
mp.drawstates()
mp.drawlsmask(ocean_color='aqua',lakes=True)
mp.drawcountries()
cbar = mp.colorbar(cols,location= 'right',pad='10%')
plt.title('NDVI on 10th june 2019')
plt.show()

# %%
"""from datetime import datetime,timedelta
time=ndvi_data.variables['time'].units[11:21]
stt = datetime.strptime(time, "%Y-%m-%d")
m=stt+timedelta(days=int(ndvi_data.variables['time'][1].data))
m

# %%
lon, lat= np.meshgrid(plon,plat)
x,y= mp(lon,lat)

# %%
cols = mp.pcolor(x,y,np.squeeze(pre[0,:,:]),cmap='jet')
mp.drawcoastlines()
mp.drawstates()
mp.drawlsmask(ocean_color='aqua',lakes=True)
mp.drawcountries()
cbar = mp.colorbar(cols,location= 'right',pad='10%')
plt.title('Precipitation on 1st june 2019')
plt.show()
# Out:
# C:\Users\Mahe\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Mahe\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   """
